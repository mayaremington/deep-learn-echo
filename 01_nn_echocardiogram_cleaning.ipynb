# %% [markdown]
# # NN for interpretation of echocardiograms: cleaning tabular data

# %%
from tensorflow import keras

import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

np.set_printoptions(suppress=True) # Suppress scientific notation where possible

# %% [markdown]
# ## Import & clean datasets

# %% [markdown]
# ### Importing video_df

# %%
# import list of video files and their measurements/metadata
# each video is 112 x 112 pixels

video_df = pd.read_csv("EchoNet-Dynamic/FileList.csv")
video_df.head()
# Out:
#              FileName         EF         ESV         EDV  FrameHeight  \
# 0  0X100009310A3BD7FC  78.498406   14.881368   69.210534          112
# 1  0X1002E8FBACD08477  59.101988   40.383876   98.742884          112
# 2  0X1005D03EED19C65B  62.363798   14.267784   37.909734          112
# 3  0X10075961BC11C88E  54.545097   33.143084   72.914210          112
# 4  0X10094BA0A028EAC3  24.887742  127.581945  169.855024          112
#
#    FrameWidth  FPS  NumberOfFrames  Split
# 0         112   50             174    VAL
# 1         112   50             215  TRAIN
# 2         112   50             104  TRAIN
# 3         112   55             122  TRAIN
# 4         112   52             207    VAL

# %%
# 10,030 video files

video_df.shape
# Out:
# (10030, 9)

# %%
video_df = video_df.set_index('FileName')
video_df
# Out:
#                            EF         ESV         EDV  FrameHeight  \
# FileName
# 0X100009310A3BD7FC  78.498406   14.881368   69.210534          112
# 0X1002E8FBACD08477  59.101988   40.383876   98.742884          112
# 0X1005D03EED19C65B  62.363798   14.267784   37.909734          112
# 0X10075961BC11C88E  54.545097   33.143084   72.914210          112
# 0X10094BA0A028EAC3  24.887742  127.581945  169.855024          112
# ...                       ...         ...         ...          ...
# 0X234005774F4CB5CD  51.724743   47.065329   97.493690          768
# 0X2DC68261CBCC04AE  62.187781   26.333478   69.642772          768
# 0X35291BE9AB90FB89  62.070762   49.064338  129.357561          768
# 0X6C435C1B417FDE8A  59.635257   57.721170  142.998978          768
# 0X5515B0BD077BE68A  46.019994   27.260394   50.500910          768
#
#                     FrameWidth  FPS  NumberOfFrames  Split
# FileName
# 0X100009310A3BD7FC         112   50             174    VAL
# 0X1002E8FBACD08477         112   50             215  TRAIN
# 0X1005D03EED19C65B         112   50             104  TRAIN
# 0X10075961BC11C88E         112   55             122  TRAIN
# 0X10094BA0A028EAC3         112   52             207    VAL
# ...                        ...  ...             ...    ...
# 0X234005774F4CB5CD        1040   50             127  TRAIN
# 0X2DC68261CBCC04AE        1024   50              66  TRAIN
# 0X35291BE9AB90FB89        1024   50             208  TRAIN
# 0X6C435C1B417FDE8A        1024   50             166  TRAIN
# 0X5515B0BD077BE68A        1024   50             126  TRAIN
#
# [10030 rows x 8 columns]

# %% [markdown]
# ### Importing & cleaning tracings_df

# %%
#import tracing measurements

tracings_df = pd.read_csv("EchoNet-Dynamic/VolumeTracings.csv")
tracings_df.head()
# Out:
#                  FileName         X1         Y1         X2         Y2  Frame
# 0  0X100009310A3BD7FC.avi  51.260417  15.348958  64.932292  69.125000     46
# 1  0X100009310A3BD7FC.avi  50.037611  17.167841  53.367222  16.321330     46
# 2  0X100009310A3BD7FC.avi  49.157378  20.407629  57.090549  18.390722     46
# 3  0X100009310A3BD7FC.avi  48.538173  23.581055  59.997339  20.667707     46
# 4  0X100009310A3BD7FC.avi  47.918968  26.754480  62.904129  22.944693     46

# %%
# 10030 videos x 2 volumes/video x 21 measurements each = 421,260
# actual df has slightly more rows than expected based on above calculation

tracings_df.shape
# Out:
# (425010, 6)

# %%
# remove ".avi" from file name to match video_df

tracings_df['FileName'] = tracings_df['FileName'].apply(lambda x: x[:-4])

# %%
tracings_df.head()
# Out:
#              FileName         X1         Y1         X2         Y2  Frame
# 0  0X100009310A3BD7FC  51.260417  15.348958  64.932292  69.125000     46
# 1  0X100009310A3BD7FC  50.037611  17.167841  53.367222  16.321330     46
# 2  0X100009310A3BD7FC  49.157378  20.407629  57.090549  18.390722     46
# 3  0X100009310A3BD7FC  48.538173  23.581055  59.997339  20.667707     46
# 4  0X100009310A3BD7FC  47.918968  26.754480  62.904129  22.944693     46

# %%
tracings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425010 entries, 0 to 425009
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   FileName  425010 non-null  object
#  1   X1        425010 non-null  float64
#  2   Y1        425010 non-null  float64
#  3   X2        425010 non-null  float64
#  4   Y2        425010 non-null  float64
#  5   Frame     425010 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 19.5+ MB

# %%
# tracing_df contains 10,025 videos, 5 fewer than video_df
# each video has exactly 2 frames that were used for tracing

grouped_tracings_df = tracings_df.groupby('FileName').nunique().sort_values(by='Frame')
grouped_tracings_df
# Out:
#                     X1  Y1  X2  Y2  Frame
# FileName
# 0X100009310A3BD7FC  41  42  41  42      2
# 0X601A0FE2BA2F9F68  40  42  40  42      2
# 0X601B706CC84025BD  42  42  40  42      2
# 0X602005216EB0FAB3  42  42  40  42      2
# 0X6020D0C5C256684D  42  42  42  42      2
# ...                 ..  ..  ..  ..    ...
# 0X3869C8E146FBD123  42  42  42  42      2
# 0X386DAB52217592A2  42  42  42  42      2
# 0X386E38E6214B10A1  42  42  42  42      2
# 0X3860318B66CC8557  42  42  39  42      2
# 0XFEBEEFF93F6FEB9   42  42  38  42      2
#
# [10025 rows x 5 columns]

# %%
# some frames have way over 21 measurements

tracings_df.groupby(['FileName', 'Frame']).count().reset_index() \
    .sort_values(by=['X1'], ascending=False).head(10)
# Out:
#                  FileName  Frame   X1   Y1   X2   Y2
# 11951  0X57AF4D24B154C573     15  168  168  168  168
# 6254   0X35A5E9C9075E56EE     44  147  147  147  147
# 6184   0X354B37A25C64276F     31  105  105  105  105
# 15781  0X6E02E0F24F63EFD7    121  105  105  105  105
# 19090   0XA20EE6C5B1F48CB     95   84   84   84   84
# 8772   0X44C18287CA978438     51   84   84   84   84
# 9000   0X46024CC33D00D4C6     33   84   84   84   84
# 9001   0X46024CC33D00D4C6     48   84   84   84   84
# 10505  0X4EA078CC4E65B6A3     61   84   84   84   84
# 14393  0X65E605F203321860     53   84   84   84   84

# %% [markdown]
# ### Identifying and handling nulls
# >- Going into this section, `video_df` had 10,030 videos and `tracing_df` had 10,025 videos
# >- By the end, both dfs will have the same 10,024 videos

# %%
# try joining grouped version of tracings_df with video_df to identify discrepancies

merged_data = pd.merge(grouped_tracings_df, video_df, on='FileName', how='outer')
merged_data.head()
# Out:
#                       X1    Y1    X2    Y2  Frame         EF        ESV  \
# FileName
# 0X100009310A3BD7FC  41.0  42.0  41.0  42.0    2.0  78.498406  14.881368
# 0X601A0FE2BA2F9F68  40.0  42.0  40.0  42.0    2.0  34.528308  86.428707
# 0X601B706CC84025BD  42.0  42.0  40.0  42.0    2.0  50.030816  71.017299
# 0X602005216EB0FAB3  42.0  42.0  40.0  42.0    2.0  59.952807  37.314740
# 0X6020D0C5C256684D  42.0  42.0  42.0  42.0    2.0  59.431978  29.482871
#
#                            EDV  FrameHeight  FrameWidth   FPS  NumberOfFrames  \
# FileName
# 0X100009310A3BD7FC   69.210534        112.0       112.0  50.0           174.0
# 0X601A0FE2BA2F9F68  132.009277        112.0       112.0  50.0           167.0
# 0X601B706CC84025BD  142.122192        112.0       112.0  50.0           137.0
# 0X602005216EB0FAB3   93.176918        112.0       112.0  50.0           153.0
# 0X6020D0C5C256684D   72.675150        112.0       112.0  62.0           150.0
#
#                     Split
# FileName
# 0X100009310A3BD7FC    VAL
# 0X601A0FE2BA2F9F68  TRAIN
# 0X601B706CC84025BD  TRAIN
# 0X602005216EB0FAB3  TRAIN
# 0X6020D0C5C256684D  TRAIN

# %%
# compare to grouped_tracings_df (10,025 rows) and video_df (10,030 rows)

merged_data.shape
# Out:
# (10031, 13)

# %%
# looks like 6 nulls in the columns from tracings_df 
# and 1 null in the columns from video_df

merged_data.isnull().sum()
# Out:
# X1                6
# Y1                6
# X2                6
# Y2                6
# Frame             6
# EF                1
# ESV               1
# EDV               1
# FrameHeight       1
# FrameWidth        1
# FPS               1
# NumberOfFrames    1
# Split             1
# dtype: int64

# %%
# the 6 entries missing from tracings_df are all at the end of the merged df

merged_data.tail(6)
# Out:
#                     X1  Y1  X2  Y2  Frame         EF        ESV         EDV  \
# FileName
# 0X5DD5283AC43CCDD1 NaN NaN NaN NaN    NaN  62.691876  36.284389   97.256001
# 0X234005774F4CB5CD NaN NaN NaN NaN    NaN  51.724743  47.065329   97.493690
# 0X2DC68261CBCC04AE NaN NaN NaN NaN    NaN  62.187781  26.333478   69.642772
# 0X35291BE9AB90FB89 NaN NaN NaN NaN    NaN  62.070762  49.064338  129.357561
# 0X6C435C1B417FDE8A NaN NaN NaN NaN    NaN  59.635257  57.721170  142.998978
# 0X5515B0BD077BE68A NaN NaN NaN NaN    NaN  46.019994  27.260394   50.500910
#
#                     FrameHeight  FrameWidth   FPS  NumberOfFrames  Split
# FileName
# 0X5DD5283AC43CCDD1        768.0      1024.0  50.0           188.0   TEST
# 0X234005774F4CB5CD        768.0      1040.0  50.0           127.0  TRAIN
# 0X2DC68261CBCC04AE        768.0      1024.0  50.0            66.0  TRAIN
# 0X35291BE9AB90FB89        768.0      1024.0  50.0           208.0  TRAIN
# 0X6C435C1B417FDE8A        768.0      1024.0  50.0           166.0  TRAIN
# 0X5515B0BD077BE68A        768.0      1024.0  50.0           126.0  TRAIN

# %%
# dropping the 6 rows from video_df

video_df = video_df.drop(['0X5DD5283AC43CCDD1', '0X234005774F4CB5CD', '0X2DC68261CBCC04AE',
'0X35291BE9AB90FB89', '0X6C435C1B417FDE8A', '0X5515B0BD077BE68A'])
video_df.shape
# Out:
# (10024, 8)

# %%
# here is the one entry missing from video_df (but present in tracings_df)
# this entry is also missing a video file

merged_data[merged_data['EF'].isnull()]
# Out:
#                       X1    Y1    X2    Y2  Frame  EF  ESV  EDV  FrameHeight  \
# FileName
# 0X4F8859C8AB4DA9CB  42.0  42.0  42.0  42.0    2.0 NaN  NaN  NaN          NaN
#
#                     FrameWidth  FPS  NumberOfFrames Split
# FileName
# 0X4F8859C8AB4DA9CB         NaN  NaN             NaN   NaN

# %%
# remove the one filename from tracings_df (42 rows)
# original length of tracings_df: 425,010

tracings_df = tracings_df[tracings_df['FileName'] != '0X4F8859C8AB4DA9CB']
tracings_df.shape
# Out:
# (424968, 6)

# %%
# 10,024 unique videos

tracings_df.groupby('FileName').nunique().shape
# Out:
# (10024, 5)

# %% [markdown]
# ## Converting tracings to volumes
# Background on tracings:
# >- Each video has 2 frames in which the LV was traced by a human
# >- For each frame, the first row is the long-axis and the rest are short axes

# %%
# add a new columnn that combines filename and frame

tracings_df['File_Frame'] = tracings_df['FileName'] + '_' + tracings_df['Frame'].astype(str)

# %%
tracings_df.head()
# Out:
#              FileName         X1         Y1         X2         Y2  Frame  \
# 0  0X100009310A3BD7FC  51.260417  15.348958  64.932292  69.125000     46
# 1  0X100009310A3BD7FC  50.037611  17.167841  53.367222  16.321330     46
# 2  0X100009310A3BD7FC  49.157378  20.407629  57.090549  18.390722     46
# 3  0X100009310A3BD7FC  48.538173  23.581055  59.997339  20.667707     46
# 4  0X100009310A3BD7FC  47.918968  26.754480  62.904129  22.944693     46
#
#               File_Frame
# 0  0X100009310A3BD7FC_46
# 1  0X100009310A3BD7FC_46
# 2  0X100009310A3BD7FC_46
# 3  0X100009310A3BD7FC_46
# 4  0X100009310A3BD7FC_46

# %%
# calculating the euclidean distance between points 1 and 2 for each row

tracings_df['Distance'] = tracings_df.apply(lambda x: np.linalg.norm(np.array((x['X1'], x['Y1'])) - 
                                           np.array((x['X2'], x['Y2']))), axis=1)

# %%
tracings_df.head(42)
# Out:
#               FileName         X1         Y1         X2         Y2  Frame  \
# 0   0X100009310A3BD7FC  51.260417  15.348958  64.932292  69.125000     46
# 1   0X100009310A3BD7FC  50.037611  17.167841  53.367222  16.321330     46
# 2   0X100009310A3BD7FC  49.157378  20.407629  57.090549  18.390722     46
# 3   0X100009310A3BD7FC  48.538173  23.581055  59.997339  20.667707     46
# 4   0X100009310A3BD7FC  47.918968  26.754480  62.904129  22.944693     46
# 5   0X100009310A3BD7FC  47.962105  29.759513  65.810920  25.221679     46
# 6   0X100009310A3BD7FC  48.167915  32.723188  68.247043  27.618326     46
# 0X100009310A3BD7FC_46 1  0X100009310A3BD7FC  50.037611  17.167841  53.367222
#                       2  0X100009310A3BD7FC  49.157378  20.407629  57.090549
#                       3  0X100009310A3BD7FC  48.538173  23.581055  59.997339
#                       4  0X100009310A3BD7FC  47.918968  26.754480  62.904129
#                       5  0X100009310A3BD7FC  47.962105  29.759513  65.810920
#
#                                 Y2  Frame             File_Frame   Distance
# File_Frame
# 0X100009310A3BD7FC_46 1  16.321330     46  0X100009310A3BD7FC_46   3.435534
#                       2  18.390722     46  0X100009310A3BD7FC_46   8.185543
#                       3  20.667707     46  0X100009310A3BD7FC_46  11.823708
#                       4  22.944693     46  0X100009310A3BD7FC_46  15.461873
#                       5  25.221679     46  0X100009310A3BD7FC_46  18.416627

# %%
# 20+ per video

short_axis.shape
# Out:
# (404920, 8)

# %%
# convert each short-axis diameter to an area

short_axis['Area'] = short_axis['Distance'] \
    .apply(lambda diameter: np.pi * np.square(diameter/2))
short_axis.head()
# Out:
#                                    FileName         X1         Y1         X2  \
# File_Frame
# 0X100009310A3BD7FC_46 1  0X100009310A3BD7FC  50.037611  17.167841  53.367222
#                       2  0X100009310A3BD7FC  49.157378  20.407629  57.090549
#                       3  0X100009310A3BD7FC  48.538173  23.581055  59.997339
#                       4  0X100009310A3BD7FC  47.918968  26.754480  62.904129
#                       5  0X100009310A3BD7FC  47.962105  29.759513  65.810920
#
#                                 Y2  Frame             File_Frame   Distance  \
# File_Frame
# 0X100009310A3BD7FC_46 1  16.321330     46  0X100009310A3BD7FC_46   3.435534
#                       2  18.390722     46  0X100009310A3BD7FC_46   8.185543
#                       3  20.667707     46  0X100009310A3BD7FC_46  11.823708
#                       4  22.944693     46  0X100009310A3BD7FC_46  15.461873
#                       5  25.221679     46  0X100009310A3BD7FC_46  18.416627
#
#                                Area
# File_Frame
# 0X100009310A3BD7FC_46 1    9.269969
#                       2   52.624122
#                       3  109.798721
#                       4  187.764765
#                       5  266.385178

# %%
# take the sum of all short-axis areas in a frame

area_sums = short_axis.reset_index(drop=True).groupby('File_Frame')['Area'] \
    .apply((lambda area: np.sum(area)))
area_sums.head()
# Out:
# File_Frame
# 0X100009310A3BD7FC_46    8651.583458
# 0X100009310A3BD7FC_61    2484.077801
# 0X1002E8FBACD08477_18    4207.797292
# 0X1002E8FBACD08477_3     7582.301720
# 0X1005D03EED19C65B_24    5011.097730
# Name: Area, dtype: float64

# %%
# create a new df that includes long axis height

vol_df = long_axis.reset_index()[['File_Frame', 'FileName', 'Distance']]
vol_df.head()
# Out:
#               File_Frame            FileName   Distance
# 0  0X100009310A3BD7FC_46  0X100009310A3BD7FC  55.486781
# 1  0X100009310A3BD7FC_61  0X100009310A3BD7FC  43.571140
# 2  0X1002E8FBACD08477_18  0X1002E8FBACD08477  40.703733
# 3   0X1002E8FBACD08477_3  0X1002E8FBACD08477  53.518362
# 4  0X1005D03EED19C65B_24  0X1005D03EED19C65B  45.947988

# %%
# rename 

vol_df = vol_df.rename(columns={'Distance': 'Height'})

# %%
# add sum of short-axis areas

vol_df['Areas'] = area_sums.reset_index()['Area']
vol_df.head()
# Out:
#               File_Frame            FileName     Height        Areas
# 0  0X100009310A3BD7FC_46  0X100009310A3BD7FC  55.486781  8651.583458
# 1  0X100009310A3BD7FC_61  0X100009310A3BD7FC  43.571140  2484.077801
# 2  0X1002E8FBACD08477_18  0X1002E8FBACD08477  40.703733  4207.797292
# 3   0X1002E8FBACD08477_3  0X1002E8FBACD08477  53.518362  7582.301720
# 4  0X1005D03EED19C65B_24  0X1005D03EED19C65B  45.947988  5011.097730

# %%
# combine areas and height to get volume

vol_df['LV_Vol'] = vol_df['Height'] * vol_df['Areas'] 
vol_df.head()
# Out:
#               File_Frame            FileName     Height        Areas  \
# 0  0X100009310A3BD7FC_46  0X100009310A3BD7FC  55.486781  8651.583458
# 1  0X100009310A3BD7FC_61  0X100009310A3BD7FC  43.571140  2484.077801
# 2  0X1002E8FBACD08477_18  0X1002E8FBACD08477  40.703733  4207.797292
# 3   0X1002E8FBACD08477_3  0X1002E8FBACD08477  53.518362  7582.301720
# 4  0X1005D03EED19C65B_24  0X1005D03EED19C65B  45.947988  5011.097730
#
#           LV_Vol
# 0  480048.513351
# 1  108234.102796
# 2  171273.058049
# 3  405792.369439
# 4  230249.857397

# %%
# drop unneeded columns

vol_df = vol_df.drop(['Height', 'Areas'], axis=1)
vol_df.head()
# Out:
#               File_Frame            FileName         LV_Vol
# 0  0X100009310A3BD7FC_46  0X100009310A3BD7FC  480048.513351
# 1  0X100009310A3BD7FC_61  0X100009310A3BD7FC  108234.102796
# 2  0X1002E8FBACD08477_18  0X1002E8FBACD08477  171273.058049
# 3   0X1002E8FBACD08477_3  0X1002E8FBACD08477  405792.369439
# 4  0X1005D03EED19C65B_24  0X1005D03EED19C65B  230249.857397

# %%
vol_df = vol_df.reset_index()

# %%
# for each FileName, returns the first of two rows 

first = vol_df.groupby('FileName')['File_Frame', "LV_Vol"].nth(0)
first.head()
# Out:
# <ipython-input-58-5bdb641f9eed>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   first = vol_df.groupby('FileName')['File_Frame', "LV_Vol"].nth(0)
#                                 File_Frame        LV_Vol
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_46  4.800485e+05
# 0X1002E8FBACD08477   0X1002E8FBACD08477_18  1.712731e+05
# 0X1005D03EED19C65B   0X1005D03EED19C65B_24  2.302499e+05
# 0X10075961BC11C88E  0X10075961BC11C88E_108  1.695839e+05
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_137  1.020074e+06

# %%
# for each FileName, returns the second of two rows 

second = vol_df.groupby('FileName').nth(1)
second.head()
# Out:
#                     index              File_Frame         LV_Vol
# FileName
# 0X100009310A3BD7FC      1   0X100009310A3BD7FC_61  108234.102796
# 0X1002E8FBACD08477      3    0X1002E8FBACD08477_3  405792.369439
# 0X1005D03EED19C65B      5   0X1005D03EED19C65B_35   85805.290368
# 0X10075961BC11C88E      7   0X10075961BC11C88E_91  373724.362746
# 0X10094BA0A028EAC3      9  0X10094BA0A028EAC3_156  775376.393540

# %%
# combines first and second "rows" column-wise

file_df = pd.merge(first, second, how='outer', on='FileName')
file_df.head()
# Out:
#                               File_Frame_x      LV_Vol_x  index  \
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_46  4.800485e+05      1
# 0X1002E8FBACD08477   0X1002E8FBACD08477_18  1.712731e+05      3
# 0X1005D03EED19C65B   0X1005D03EED19C65B_24  2.302499e+05      5
# 0X10075961BC11C88E  0X10075961BC11C88E_108  1.695839e+05      7
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_137  1.020074e+06      9
#
#                               File_Frame_y       LV_Vol_y
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_61  108234.102796
# 0X1002E8FBACD08477    0X1002E8FBACD08477_3  405792.369439
# 0X1005D03EED19C65B   0X1005D03EED19C65B_35   85805.290368
# 0X10075961BC11C88E   0X10075961BC11C88E_91  373724.362746
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_156  775376.393540

# %%
# no change in num rows

file_df.shape
# Out:
# (10024, 5)

# %%
def get_vol_type(frame_x, vol_x, frame_y, vol_y):
    '''For each row, determines which volume (and corresponding frame) represents
    EDV versus ESV'''
    
    if vol_x > vol_y:
        EDV_frame = frame_x
        EDV = vol_x
        ESV_frame = frame_y
        ESV = vol_y
    if vol_x < vol_y:
        ESV_frame = frame_x
        ESV = vol_x
        EDV_frame = frame_y
        EDV = vol_y
    return EDV_frame, EDV, ESV_frame, ESV

# %%
# adds 4 new columns to file_df

file_df[['EDV_frame', 'EDV', 'ESV_frame', 'ESV']] = file_df.apply(lambda v: get_vol_type(v['File_Frame_x'], v['LV_Vol_x'], v['File_Frame_y'], v['LV_Vol_y']), axis=1, result_type='expand')

# %%
file_df
# Out:
#                               File_Frame_x      LV_Vol_x  index  \
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_46  4.800485e+
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_156  775376.393540

# %%
# calculating EF (based on calculations on tracing data)

file_df['EF'] = ((file_df['EDV'] - file_df['ESV']) / file_df['EDV']) * 100

# %%
file_df.head()
# Out:
#                                  EDV_frame           EDV  \
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_46  4.800485e+05
# 0X1002E8FBACD08477    0X1002E8FBACD08477_3  4.057924e+05
# 0X1005D03EED19C65B   0X1005D03EED19C65B_24  2.302499e+05
# 0X10075961BC11C88E   0X10075961BC11C88E_91  3.737244e+05
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_137  1.020074e+06
#
#                                  ESV_frame            ESV         EF
# FileName
# 0X100009310A3BD7FC   0X100009310A3BD7FC_61  108234.102796  77.453507
# 0X1002E8FBACD08477   0X1002E8FBACD08477_18  171273.058049  57.792933
# 0X1005D03EED19C65B   0X1005D03EED19C65B_35   85805.290368  62.733836
# 0X10075961BC11C88E  0X10075961BC11C88E_108  169583.928426  54.623261
# 0X10094BA0A028EAC3  0X10094BA0A028EAC3_156  775376.393540  23.988204

# %%
# EFs are all positive and have reasonable stats

file_df.describe()
# Out:
#                 EDV           ESV            EF
# count  1.002400e+04  1.002400e+04  10024.000000
# mean   6.323251e+05  2.917269e+05     55.282175
# std    4.051484e+05  2.322262e+05     12.581399
# min    4.246420e+03  1.737235e+03      0.846479
# 25%    3.803200e+05  1.533810e+05     51.141748
# 50%    5.263554e+05  2.227294e+05     58.673566
# 75%    7.633499e+05  3.540071e+05     63.555337
# max    6.165758e+06  3.084905e+06     94.757421

# %%
# splice out FileNames

file_df['EDV_frame'] = file_df.EDV_frame.str.split('_').str[1]
file_df['ESV_frame'] = file_df.ESV_frame.str.split('_').str[1]

# %%
file_df.head()
# Out:
#                    EDV_frame           EDV ESV_frame            ESV         EF
# FileName
# 0X100009310A3BD7FC        46  4.800485e+05        61  108234.102796  77.453507
# 0X1002E8FBACD08477         3  4.057924e+05        18  171273.058049  57.792933
# 0X1005D03EED19C65B        24  2.302499e+05        35   85805.290368  62.733836
# 0X10075961BC11C88E        91  3.737244e+05       108  169583.928426  54.623261
# 0X10094BA0A028EAC3       137  1.020074e+06       156  775376.393540  23.988204

# %%
# merge datasets

video_df = pd.merge(video_df, file_df, how='outer', on='FileName')
video_df.head()
# Out:
#                          EF_x       ESV_x       EDV_x  FrameHeight  \
# FileName
# 0X100009310A3BD7FC  78.498406   14.881368   69.210534          112
# 0X1002E8FBACD08477  59.101988   40.383876   98.742884          112
# 0X1005D03EED19C65B  62.363798   14.267784   37.909734          112
# 0X10075961BC11C88E  54.545097   33.143084   72.914210          112
# 0X10094BA0A028EAC3  24.887742  127.581945  169.855024          112
#
#                     FrameWidth  FPS  NumberOfFrames  Split EDV_frame  \
# FileName
# 0X100009310A3BD7FC         112   50             174    VAL        46
# 0X1002E8FBACD08477         112   50             215  TRAIN         3
# 0X1005D03EED19C65B         112   50             104  TRAIN        24
# 0X10075961BC11C88E         112   55             122  TRAIN        91
# 0X10094BA0A028EAC3         112   52             207    VAL       137
#
#                            EDV_y ESV_frame          ESV_y       EF_y
# FileName
# 0X100009310A3BD7FC  4.800485e+05        61  108234.102796  77.453507
# 0X1002E8FBACD08477  4.057924e+05        18  171273.058049  57.792933
# 0X1005D03EED19C65B  2.302499e+05        35   85805.290368  62.733836
# 0X10075961BC11C88E  3.737244e+05       108  169583.928426  54.623261
# 0X10094BA0A028EAC3  1.020074e+06       156  775376.393540  23.988204

# %%
# no change in number of rows
video_df.shape
# Out:
# (10024, 13)

# %% [markdown]
# ###  Comparing calculated vs original EF values

# %%
# compare EF columns

video_df['EF_diff'] = video_df['EF_x'] - video_df['EF_y']
video_df.head()
# Out:
#                          EF_x       ESV_x       EDV_x  FrameHeight  \
# FileName
# 0X100009310A3BD7FC  78.498406   14.881368   69.210534          112
# 0X1002E8FBACD08477  59.101988   40.383876   98.742884          112
# 0X1005D03EED19C65B  62.363798   14.267784   37.909734          112
# 0X10075961BC11C88E  54.545097   33.143084   72.914210          112
# 0X10094BA0A028EAC3  24.887742  127.581945  169.855024          112
#
#                     FrameWidth  FPS  NumberOfFrames  Split EDV_frame  \
# FileName
# 0X100009310A3BD7FC         112   50             174    VAL        46
# 0X1002E8FBACD08477         112   50             215  TRAIN         3
# 0X1005D03EED19C65B         112   50             104  TRAIN        24
# 0X10075961BC11C88E         112   55             122  TRAIN        91
# 0X10094BA0A028EAC3         112   52             207    VAL       137
#
#                            EDV_y ESV_frame          ESV_y       EF_y   EF_diff
# FileName
# 0X100009310A3BD7FC  4.800485e+05        61  108234.102796  77.453507  1.044899
# 0X1002E8FBACD08477  4.057924e+05        18  171273.058049  57.792933  1.309055
# 0X1005D03EED19C65B  2.302499e+05        35   85805.290368  62.733836 -0.370037
# 0X10075961BC11C88E  3.737244e+05       108  169583.928426  54.623261 -0.078164
# 0X10094BA0A028EAC3  1.020074e+06       156  775376.393540  23.988204  0.899537

# %%
# most videos have only slight differences between EFs - but there are very large differences

video_df['EF_diff'].describe()
# Out:
# count    10024.000000
# mean         0.465091
# std          3.070866
# min        -43.691952
# 25%         -0.178093
# 50%          0.396985
# 75%          1.033410
# max         77.269984
# Name: EF_diff, dtype: float64

# %%
# approx 50 videos have EF differences smaller (more negative) than -5

video_df.sort_values(by='EF_diff').head(60)
# Out:
#                          EF_x       ESV_x       EDV_x  FrameHeight  \
# FileName
# 0X2AC09763183674E8  29.220287  283.258190  400.196863          112
# 0X67F8AC58B0BAA98   37.406850   57.279656   91.511061          112
# 0X13D1459C51B5C32E  34.204924   50.835267   77.263027          112
# 0X5D38D994C2490EAE  43.759989   48.980026   87.091067          112
# 0X67E8F2D130F1A55   45.258705   72.907135  133.184893          112
# 0X3D8353611168F743  47.406198   29.426244   55.950022          112
# 0X526BA02D476E9274  47.983035   42.468391   81.643346          112
# 0X62120814160BA377  34.608729  117.737668  180.051047          112
# 0X280B7441A7E287B2  39.504455   15.406010   25.466354          112
# 0X500FC4E8716B0A8F  46.766109  155.843559  292.752522          112
# 0XB8513240ED5E94    50.164101  128.904509  258.657940          112
# 0X57E5F01C8FBC44B2  34.604620  100.293981  153.365544          112
# 0X2FE99C7939456141  41.761586   59.367133  101.938100          112
# 0X436381EDEAF56C17  37.317993   53.933722   86.043387          112
#
#                     FrameWidth  FPS  NumberOfFrames  Split EDV_frame  \
# FileName
# 0X2AC09763183674E8         112   43             131    VAL        64
# 0X67F8AC58B0BAA98          112   50             201  TRAIN       198
# 0X13D1459C51B5C32E         112   50             107  TRAIN        43
# 0X5D38D994C2490EAE         112   50             157  TRAIN        75
# 0X67E8F2D130F1A55          112   50             142   TEST        20
# 0X3D8353611168F743         112   50             173  TRAIN        43
# 0X526BA02D476E9274         112   50             151  TRAIN        93
# 0X62120814160BA377         112   50             204  TRAIN       203
# 0X280B7441A7E287B2         112   57             183    VAL         1
# 0X500FC4E8716B0A8F         112   40             161   TEST        97
# 0XB8513240ED5E94           112   48             193  TRAIN       115
# 0X69C718B691DF9F1          112   50             141  TRAIN         0
# 0X69FF2B134E1DF1B1         112   50             118  TRAIN        59
# 0X6C124671AA84BFE1         112   50             149    VAL       112
# 0X4154F112065C857B         112   50             497    VAL        45
# 0X59D1140D8320A782         112   50             210  TRAIN        56
# 0X75ED030E56E85A27         112   50             178    VAL        42
# 0X59B507E8C14DA46B         112   47             213  TRAIN        69
# 0X53BD50EB0C43D30D         112   50             144   TEST        51
# 0X6E5824E76BEB3ECA         112   51             230    VAL        78
# 0X5C732BCF53162A65         112   50             187   TEST        66
# 0X278A875DF27E7F42         112   50             149  TRAIN        70
# 0X76CF3E993E9964A9         112   59             109  TRAIN        60
# 0X4DEAED0369D251DE         112   80             325  TRAIN        82
# 0X2507255D8DC30B4E         112   50             174   TEST         0
# 0X27A14489647DFCB          112   43             117  TRAIN        13
# 0X7B1F112049D754D9         112   50             172   TEST        41
# 0X454C1F4146B14E0E         112   50             152  TRAIN        56
# 0X4B3A70F6BD40224B         112   50             134  TRAIN       112
# 0X49620F7B3E4CA28A         112   50             172    VAL        61
# 0X56BAEFC36506EC74         112   47             213  TRAIN        84
# 0X6E02E0F24F63EFD7         112   50             145  TRAIN       121
# 0X47760ED572E13C7A         112   52             192    VAL       176
# 0X49EC1927F5747B19         112   50             173  TRAIN       110
# 0X367085DDC2E90657         112   50             231  TRAIN       114
# 0X7934C29136B9E43E         112   50             142  TRAIN        53
# 0X45D67C2F0E610EE          112   59             167  TRAIN        13
# 0X3A79044052AC3197         112   50             160  TRAIN        52
# 0X59D5F41F45601E03         112   50             137  TRAIN        17
# 0X208FBB50F39AAF69         112   53             167  TRAIN        67
# 0X40363DBD828783F          112   50             210  TRAIN       106
# 0X200A81BEC98DEB6D         112   50             135    VAL        81
# 0X3C63C23E5B0823D          112   50             172    VAL        15
# 0X766B7B0ABDB07CD5         112   50             173  TRAIN        18
# 0X3E8B547584BD000D         112   50             167  TRAIN       104
# 0XAF14E70264D4B68          112   52              78  TRAIN        77
# 0X57FE3361D451C871         112   50             147  TRAIN       140
# 0X6050E603BC35F0D          112   50             220    VAL       125
# 0X5B0E31F05985CD68  31.796481   64.979652   95.273166          112
# 0X7C053B5DB5BAEB83  52.203125   53.101591  111.098457          112
# 0X51DF5916C8A5E638  28.223684   74.321171  103.545536          112
# 0X4361231DA99A3480  24.296297   66.503261   87.846774          112
# 0X9581FCED8A0EB28   45.500777   72.658978  133.321126          112
# 0X33763ECB684188DA  36.981117   53.781234   85.341459          112
# 0X6CA28B9E9EEFF603  22.639545  203.039366  262.458858          112
# 0X7E9BC4EAB9EEA7F9  21.742019  205.703677  262.853289          112
# 0X3999802A1B03A98E  18.531236  104.298100  128.022195          112
#
#                     FrameWidth  FPS  NumberOfFrames  Split EDV_frame  \
# FileName
# 0X354B37A25C64276F         112   50              71  TRAIN        31
# 0X65E605F203321860         112   50              67  TRAIN        32
# 0X973E4A9DAADDF9F          112   50              57  TRAIN        49
# 0X2AD994F98C491FA6         112   50             150    VAL        41
# 0X37F9E9981E207C04         112   50             110  TRAIN        75
# 0X36C5A15AC7FC6AAA         112   47             229  TRAIN        74
# 0X411E89F93DAB415A         112   54             109  TRAIN        48
# 0X28980B95F9769CE7         112   62             149  TRAIN         3
# 0X5B6FCBB75BF8FCB7         112   50             105  TRAIN        84
# 0X4EA078CC4E65B6A3         112   50              87  TRAIN        61
# 0X665B15BB5ABDCCFF         112   30              91  TRAIN        70
# 0X44C18287CA978438         112   50             147  TRAIN        51
# 0X46024CC33D00D4C6         112   50             105  TRAIN        33
# 0X4BBA9C8FB485C9AB         112   50             154  TRAIN         0
# 0X7F33CFDB31ADCD6A         112   50             157  TRAIN        95
# 0X7F65556BA84EBBCB         112   47             126  TRAIN        45
# 0X1E12EEE43FD913E5         112   47             145   TEST        42
# 0X53C185263415AA4F         112   30              52  TRAIN        37
# 0X655399113DAA4ECC         112   50              80  TRAIN         0
# 0X4E9F08061D109568         112   50              82   TEST         1
# 0X52A92D8D4C0BB36B         112   50             107  TRAIN        96
# 0X753AA26EA352BBB          112   50              60  TRAIN        32
# 0X3269691452F4F42A         112   50             146    VAL       106
# 0X12430512E2BBCD55         112   50              73  TRAIN        38
# 0X642E639A8CDE539B         112   50             183  TRAIN       141
# 0X3317BCA5B123B1DA         112   50             172  TRAIN        58
# 0X3A6E1BAA9065D40          112   50              52  TRAIN        35
# 0X6FDBAFEA74C9BC7E         112   46             159  TRAIN        80
# 0XA20EE6C5B1F48CB          112   50             144  TRAIN        95
# 0X3EB0FC2695B0AB5F         112   50             175  TRAIN        88
# 0X43DE853BD6E0C849         112   50             197   TEST        97
# 0X1CF4B07994B62DBB         112   50              58   TEST        39
# 0XDA9164EAE828591          112   50             131  TRAIN       108
# 0X3693781992586497         112   41              77  TRAIN        39
# 0X775319C257A48042         112   50             201   TEST        95
# 0X7FE48E5475ADE2E3         112   50             155    VAL       119
# 0X592F522398D46067         112   50             212  TRAIN       102
# 0XACACEACDB6D7111          112   50             108  TRAIN        35
# 0XA0FF3E0630F3902          112   50              99  TRAIN        33
# 0X698851733B8DB622         112   43              69  TRAIN        28
# 0X3A6E1BAA9065D40   8.805656e+05        45  3.830174e+05  56.503246  24.696943
# 0X6FDBAFEA74C9BC7E  1.197349e+05        95  5.189496e+04  56.658436  21.129552
# 0XA20EE6C5B1F48CB   1.048414e+06       116  3.024725e+05  71.149511  19.163210
# 0X3EB0FC2695B0AB5F  5.457549e+05        16  1.654995e+05  69.675117  16.334567
# 0X43DE853BD6E0C849  1.020703e+06        50  5.090068e+05  50.131728  14.219275
# 0X1CF4B07994B62DBB  1.043216e+06        31  4.191268e+05  59.823584  11.472515
# 0XDA9164EAE828591   1.005286e+06        86  2.784509e+05  72.301329  10.214297
# 0X3693781992586497  3.153710e+05        47  1.893017e+05  39.974934   9.700726
# 0X775319C257A48042  1.084669e+06       117  7.364905e+05  32.099993   9.335058
# 0X7FE48E5475ADE2E3  9.437886e+05        94  7.152127e+05  24.218968   6.404899
# 0X592F522398D46067  2.426094e+05        60  1.067673e+05  55.992116   6.115985
# 0XACACEACDB6D7111   8.834541e+05        53  4.956156e+05  43.900242   5.801871
# 0XA0FF3E0630F3902   6.200223e+05        43  4.677577e+05  24.557920   5.564723
# 0X698851733B8DB622  2.455959e+05        43  1.576356e+05  35.815048   5.520863
# 0X51EBAEFBADEB15E9  2.027814e+06       103  1.940477e+06   4.306969   5.336825
# 0X5B0E31F05985CD68  7.746426e+05        29  5.693717e+05  26.498786   5.297695
# 0X7C053B5DB5BAEB83  7.264686e+05       122  3.856626e+05  46.912696   5.290428
# 0X51DF5916C8A5E638  6.941777e+05        61  5.342540e+05  23.037862   5.185821
# 0X4361231DA99A3480  3.054845e+05       114  2.470304e+05  19.134854   5.161443
# 0X9581FCED8A0EB28   5.289481e+05        15  3.145455e+05  40.533767   4.967009
# 0X33763ECB684188DA  1.051755e+06       105  7.140343e+05  32.110214   4.870903
# 0X6CA28B9E9EEFF603  1.277264e+06        57  1.049901e+06  17.800784   4.838761
# 0X7E9BC4EAB9EEA7F9  7.036322e+05        48  5.837665e+05  17.035280   4.706739
# 0X3999802A1B03A98E  2.107897e+06       136  1.815611e+06  13.866203   4.665032

# %%
# dropping videos with EF_differences less than -5

video_df = video_df[(video_df['EF_diff'] >= -5)]

# %%
# dropping videos with EF_differences greater than 5

video_df = video_df[(video_df['EF_diff'] <= 5)]

# %%
# dropped a total of 95 videos

video_df.shape
# Out:
# (9929, 14)

# %%
# confirming differences are much smaller after dropping 95 most extreme videos

video_df['EF_diff'].describe()
# Out:
# count    9929.000000
# mean        0.443055
# std         1.012311
# min        -4.825463
# 25%        -0.173447
# 50%         0.397697
# 75%         1.027362
# max         4.967009
# Name: EF_diff, dtype: float64

# %% [markdown]
# ## Prepare tabular data for video processing

# %%
# create a new df with info we'll need for processing videos

video_files = video_df[['Split', 'NumberOfFrames', 'EDV_frame', 'EDV_y', 'ESV_frame', 'ESV_y', 'EF_y']]

# %%
video_files = video_files.rename(columns={'NumberOfFrames': 'NumFrames', 'EDV_y': 'EDV', 'ESV_y': 'ESV', 'EF_y': 'EF'})

# %%
video_files = video_files.reset_index()

# %%
video_files.head()
# Out:
#              FileName  Split  NumFrames EDV_frame           EDV ESV_frame  \
# 0  0X100009310A3BD7FC    VAL        174        46  4.800485e+05        61
# 1  0X1002E8FBACD08477  TRAIN        215         3  4.057924e+05        18
# 2  0X1005D03EED19C65B  TRAIN        104        24  2.302499e+05        35
# 3  0X10075961BC11C88E  TRAIN        122        91  3.737244e+05       108
# 4  0X10094BA0A028EAC3    VAL        207       137  1.020074e+06       156
#
#              ESV         EF
# 0  108234.102796  77.453507
# 1  171273.058049  57.792933
# 2   85805.290368  62.733836
# 3  169583.928426  54.623261
# 4  775376.393540  23.988204

# %%
video_files.shape
# Out:
# (9929, 8)

# %%
video_files[video_files['FileName'] == '0X1A76A1A8448B456']
# Out:
#               FileName  Split  NumFrames EDV_frame            EDV ESV_frame  \
# 835  0X1A76A1A8448B456  TRAIN        206         2  369574.080293        18
#
#               ESV         EF
# 835  155478.99363  57.930222

# %%
video_files[video_files['FileName'] == '0X1A349D84388BD74B']
# Out:
#                FileName  Split  NumFrames EDV_frame            EDV ESV_frame  \
# 820  0X1A349D84388BD74B  TRAIN        177        44  390899.451822        61
#
#                ESV         EF
# 820  154799.880058  60.399054

# %%
video_files[video_files['FileName'] == '0X1AE20B8AE3B5E9EF']
# Out:
#                FileName  Split  NumFrames EDV_frame            EDV ESV_frame  \
# 860  0X1AE20B8AE3B5E9EF  TRAIN        194       100  522782.360074       118
#
#                ESV        EF
# 860  203660.688171  61.04293

# %% [markdown]
# ### Train-test split

# %%
# split into train(includes train and val) and test according to division of original dataset

train_videos = video_files[video_files['Split'] == 'TRAIN']
val_videos = video_files[video_files['Split'] == 'VAL']
test_videos = video_files[video_files['Split'] == 'TEST']

# %%
train_videos["Split"] = "Train"
# Out:
# <ipython-input-88-7554002ae79d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_videos["Split"] = "Train"

# %%
train_videos = train_videos.reset_index(drop=True)
train_videos.tail()
# Out:
#                FileName  Split  NumFrames EDV_frame            EDV ESV_frame  \
# 7387  0XFD9464CF9E40B66  Train        142       106  477658.666810       121
# 7388  0XFDC39A88895DE1E  Train        181        42  385448.237813        63
# 7389  0XFDFBA5702E94ABF  Train        192       100  731582.452357       117
# 7390  0XFDFD17B7CCFE5AF  Train        268        66  390980.349851        85
# 7391  0XFEBEEFF93F6FEB9  Train        109        25  375613.382114        38
#
#                 ESV         EF
# 7387  137513.011648  71.211030
# 7388  164745.848585  57.258632
# 7389  338787.294499  53.691167
# 7390  145372.048701  62.818579
# 7391  257292.450725  31.500723

# %%
# approximately 75% train

train_videos.shape
# Out:
# (7392, 8)

# %%
val_videos["Split"] = "Val"
# Out:
# <ipython-input-91-0fd838ecb31c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_videos["Split"] = "Val"

# %%
val_videos = val_videos.reset_index(drop=True)
val_videos.tail()
# Out:
#                FileName Split  NumFrames EDV_frame            EDV ESV_frame  \
# 1268  0XFBD22BB93EE05C1   Val        193        39  510239.407446        56
# 1269  0XFCC2AF8E23AFBA8   Val        161        41  562010.456102        57
# 1270  0XFD06AD51C6DA6E5   Val        191        47  426498.897500        62
# 1271  0XFDB874C30A9C923   Val        184        53  613907.961534        73
# 1272  0XFE83FF3D3B13C3A   Val        192        49  266065.065718        67
#
#                 ESV         EF
# 1268  206763.703985  59.477120
# 1269  213292.246691  62.048349
# 1270  184570.140624  56.724357
# 1271  493886.860063  19.550341
# 1272   98194.090732  63.093956

# %%
# approx 12.5% val

val_videos.shape
# Out:
# (1273, 8)

# %%
test_videos["Split"] = "Test"
# Out:
# <ipython-input-94-65ef65f7f850>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_videos["Split"] = "Test"

# %%
test_videos = test_videos.reset_index(drop=True)
test_videos.tail()
# Out:
#                FileName Split  NumFrames EDV_frame            EDV ESV_frame  \
# 1259  0XECF82DC9301EE77  Test        176        91  734262.514179       111
# 1260  0XF557EF658FD13D0  Test        179         0  485878.226316        20
# 1261  0XF6661AF354401A5  Test        221        93  610161.985847       111
# 1262  0XF829F634971A0F7  Test        183        48  472216.649112        66
# 1263  0XFE6E32991136338  Test        120        31  462524.953885        45
#
#                 ESV         EF
# 1259  269118.289836  63.348491
# 1260  232627.262127  52.122312
# 1261  213721.125544  64.973051
# 1262  173155.674447  63.331307
# 1263  322695.862701  30.231686

# %%
# approx 12.5% test

test_videos.shape
# Out:
# (1264, 8)

# %% [markdown]
# ## Process videos

# %%
import tensorflow.keras.utils as utils

# %%
def process_df(df):
    '''Takes in a echocardiogram video clip and extracts 3 images: 
    one at end-diastole, one at end-systole, and one in between (other).'''
    
    for row in df.itertuples():
        # load and open videos
        path = "EchoNet-Dynamic/Videos/" + row.FileName + ".avi"
        cap = cv2.VideoCapture(path)
        frames = []
        while cap.isOpened():
            ret, frame = cap.read()
            # if frame is read correctly, ret is true
            if not ret:
                break
            frames.append(frame)
        
        #print(f'Reported num of frames: {row.NumFrames}')
        #print(f'Actual num of frames: {len(frames)}')
        
        # select and save EDV frames
        #print(f'EDV frame: {row.EDV_frame}')
        EDV_image = frames[int(row.EDV_frame) - 1] # account for 0 indexing
        EDV_path = row.Split + "_Images/EDV/" + row.FileName + '_EDV.jpg'   
        tf.keras.preprocessing.image.save_img(EDV_path, np.array(EDV_image), scale=False)
        
        # select and save ESV frames
        #print(f'ESV frame: {row.ESV_frame}')
        ESV_image = frames[int(row.ESV_frame) - 1] # account for 0 indexing
        ESV_path = row.Split + "_Images/ESV/" + row.FileName + '_ESV.jpg'  
        tf.keras.preprocessing.image.save_img(ESV_path, np.array(ESV_image), scale=False)
        
        # select and save an "Other" frame
        other_frame = np.around((int(row.EDV_frame) + int(row.ESV_frame)) / 2)
        #print(f'Other frame: {other_frame}')
        other_image = frames[int(other_frame) - 1] # account for 0 indexing
        other_path = row.Split + "_Images/Other/" + row.FileName + '_Other.jpg'
        tf.keras.preprocessing.image.save_img(other_path, np.array(other_image), scale=False)
        
        cap.release()

# %%
process_df(train_videos.iloc[6000:8000])

# %%
process_df(val_videos)

# %%
process_df(test_videos)
